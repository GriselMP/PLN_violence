# %% [markdown]
# <a href="https://colab.research.google.com/github/GriselMP/PLN_violence/blob/main/ExtraerTweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tweepy
import json
import os


class TweesListerner(tweepy.StreamListener):
	def on_connect(self):
		print("Conected")

	def on_status(self,status):
		print(status.text)
		if len(status.text)>50:
			#the archive name to write the information
			data=open(path,'a')
			data.write(str(status.text))
			data.write(os.linesep)
			data.close()

	def on_error (self, status_code):
		print("Error", status_code)


#Validation KEY of twitter
consumer_key = "XXXXXXXXXXXXXXXXXXXXXXXX" #Counsumer Key 
consumer_secret = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX" #Consumer Key Secret
access_token ="XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX" #Access Token
access_token_secret= "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX" #Access Token Secret

auth = tweepy.OAuthHandler (consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True, wait_on_rate_limit_notify=True)


stream= TweesListerner()
streamingApi = tweepy.Stream(auth=api.auth, listener=stream)
streamingApi.filter(
	track=["word1","word2","word3","wordn"], #filter by key words
	locations=[x,x,x,x], #filter by locations
	languages=["es"], #filter by key lenguaje
)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# @elgatopolitico_ El problema es que no ganó para ser agitador callejero y vulgar (reconozco que es muy bueno para e… https://t.co/OjrGX9MuFA
# RT @FRepublicanaPy: Mujeres, hombres, jóvenes o adultos mayores en cada rincón del país nos dan su apoyo porque saben que el único proyecto…
# Mi vieja me dice hoy como te fue en el dentista?
# Le digo.. mañana tengo turno ma
# Me dice y ahora que haces te acos… https://t.co/kwVL1PtjS8
# RT @RICHARD23GD: Se me hace gorda https://t.co/PCJTwQiOMJ
# RT @tresmasciento: Estar en contra del mundial del Catar porque allí no se respetan los derechos de las mujeres y de los homosexuales pero…
# RT @PochocloOficial: El golpeador de mujeres mas cuerdo https://t.co/kc1ve1i5p0
# RT @StockAvenger1: Yo soy el insecto de Fernández y me quedo en Bali hasta Diciembre 2023 fingiendo un ACV mientras me tiran la piola, dejá…
# Que miedo jajaja
# ...
