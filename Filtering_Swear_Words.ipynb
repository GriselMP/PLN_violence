# %% [markdown]
# <a href="https://colab.research.google.com/github/GriselMP/PLN_violence/blob/main/Filtering_Swear_Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#filtering tweets that contain words from the swear words for insult women

swear_words=["gorda","india","sirvienta","puta","zorra","perra","retrasada","inútil","virgen","machorra",
"estúpida","naca","idiota","teibolera","vedette","gata","mierda","malparida","obesa","vendida",
"prostituta","vaca","cerda","golfa","chaquetera","feminazi","fea","tetas","asesina","arrastrada",
"robamaridos","bastarda","maldita","escoria","tonta","miserable","torpe","pendeja","coger","puta madre",
"culo","mamahuevos","lame-botas","boba","pinche","panocha","feminismo","pobre","negra","señora",
"bruja","arpía","fodonga","vieja","asquerosa","chismosa","mentirosa","dramática","perdedora","ramera","hija de puta",
"mojigata","barata","histérica","neurótica","solterona","ama de casa","mantenida","imbécil","lesbiana","baja novios",
"mujeres","mujer","zopilota","actriz"]

def filter_swear_words(lista1,lista2):
  out=[]
  for elem in lista1:
    if elem in lista2:
      out=lista1
  return out

#read all data extracted from Twitter with the script
f = open("/content/drive/MyDrive/basesTwitter/dataset_spaces.txt", "r")
tuits=f.readlines()
f.close()

#extract all tweets that contain swear words and save into a txt file
fi = open("/content/drive/MyDrive/basesTwitter/candidatosV.txt", "w")
for tuit in tuits:
    frase=tuit.split()
    vi=filter_swear_words(frase,swear_words)
    filaV=" ".join(vi)

    fi.write(filaV+"\n")
fi.close()

# %%
f = open("/content/drive/MyDrive/basesTwitter/dataset_spaces.txt", "r")
tuits=f.readlines()
f.close()

for elemento in tuits:
  print(elemento)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# @rodherrerachile Que problema haberle dado la sede de este mundial a Qatar, todo es prohibido,se murieron muchos tr… https://t.co/zuLHOZDSqK
#
# y si twitter nunca existió y en realidad twitter son las amistades que hicimos en el camino?
#
# RT @GAESPPAL35: #18Nov|🇻🇪 🎄 ¡Comando Nacional Anti-extorsión y Secuestro! 💂‍♂️💂‍♂️
#
# Somos hombres y mujeres calificados, tributando en bene…
#
# @_nopsy Entiendo! Muchas gracias por la info, me hacía falta, espero que todo este desastre se arregle. Me siento t… https://t.co/AFqxOL3Pnv
#
# RT @OscarAthie: @azucenau Nadie dijo Indio pata rajada, y quien hasta cantó Naca naca, fue la diputada Clemente de Morena. La Marcha 13N fu…
#
# Si hay una mujer a la quiero mil y admiro mil más es @bego_roja ❤
#
# La fuerza de Tarea Conjunta Barlovento, desplegada en Higuerote, en apoyo a la población afectada. Nuestra FANB est… https://t.co/rqUvD1BtBo
#
# ...
